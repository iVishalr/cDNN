# %%
import numpy as np
import pandas as pd
import os
import random

# %%
layer_weight_dims = [19200,20,10,1]
layer_bias_dims = [20,10,1]

# %%
a = np.mgrid[0:256:19200j]

# %%
a = a.reshape((-1,1)).astype('uint8')

# %%
np.random.shuffle(a)

# %%
b = a.reshape((80,80,3))

# %%
from PIL import Image
import matplotlib.pyplot as plt

PIL_image = Image.fromarray(b)
plt.imshow(PIL_image)
plt.show()

# %%
MODEL_PATH = "./model/model_cats_vs_dogs4_new.t7"

f = open(MODEL_PATH,"r")
data = f.read()
f.close()

layer1_weight = data.split(" ")[:384000]
layer1_weight = np.array(layer1_weight).astype(float)
layer1_weight.shape
# Out:
# (384000,)

# %%
layer1_weight = layer1_weight > 0.5

# %%
layer1_weight = layer1_weight.astype('uint8')

# %%
layer1_weight = layer1_weight.reshape((19200,20))
test = layer1_weight

# %%
layer1_weight = layer1_weight.T

# %%
layer1_weight[0].shape
# Out:
# (19200,)

# %%
final_image = np.zeros((19200,1))
for images in layer1_weight:
    temp = images.reshape((-1,1))
    final_image = np.add(final_image,temp/20)

#div_factor = np.array([[20]])
#final_image = np.divide(final_image,div_factor).astype('uint8')
final_image = final_image.reshape((80,80,3)).astype('uint8') > 0.5

# %%
PIL_image = Image.fromarray(final_image)
plt.imshow(PIL_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2644             typekey = (1, 1) + shape[2:], arr["typestr"]
# -> 2645             mode, rawmode = _fromarray_typemap[typekey]
#    2646         except KeyError:
#
# KeyError: ((1, 1, 3), '|b1')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-9bedbf7730af> in <module>
# ----> 1 PIL_image = Image.fromarray(final_image)
#       2 plt.imshow(PIL_image)
#       3 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2645             mode, rawmode = _fromarray_typemap[typekey]
#    2646         except KeyError:
# -> 2647             raise TypeError("Cannot handle this data type")
#    2648     else:
#    2649         rawmode = mode
#
# TypeError: Cannot handle this data type

# %%
PIL_image = Image.fromarray(test.astype('uint8'))
plt.imshow(PIL_image)
plt.show()
